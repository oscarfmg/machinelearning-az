# %% [markdown]
# <a href="https://colab.research.google.com/github/oscarfmg/machinelearning-az/blob/develop/update/Part%201%20-%20Data%20Preprocessing/Section%202%20--------------------%20Part%201%20-%20Data%20Preprocessing%20--------------------/Python/data_preprocessing_template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Preprocessing Template

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from google.colab import drive
# !git clone https://github.com/oscarfmg/machinelearning-az.git
# Out:
# Cloning into 'machinelearning-az'...
# remote: Enumerating objects: 10878, done.
# remote: Counting objects: 100% (292/292), done.
# remote: Compressing objects: 100% (147/147), done.
# remote: Total 10878 (delta 187), reused 145 (delta 145), pack-reused 10586 (from 2)
# Receiving objects: 100% (10878/10878), 315.89 MiB | 34.63 MiB/s, done.
# Resolving deltas: 100% (326/326), done.
# Updating files: 100% (20461/20461), done.

# %%
# !ls ./machinelearning-az/update/Part\ 1\ -\ Data\ Preprocessing/Section\ 2\ --------------------\ Part\ 1\ -\ Data\ Preprocessing\ --------------------/Python/Data.csv
import os
p = os.path.join('.','machinelearning-az','update','Part 1 - Data Preprocessing','Section 2 -------------------- Part 1 - Data Preprocessing --------------------','Python','Data.csv')
print(p)
os.path.isfile(p)
# Out:
# './machinelearning-az/update/Part 1 - Data Preprocessing/Section 2 -------------------- Part 1 - Data Preprocessing --------------------/Python/Data.csv'
# ./machinelearning-az/update/Part 1 - Data Preprocessing/Section 2 -------------------- Part 1 - Data Preprocessing --------------------/Python/Data.csv
# True

# %% [markdown]
# ## Importing the dataset

# %%
dataset = pd.read_csv(p)
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %% [markdown]
# ## Splitting the dataset into the Training set and Test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)
